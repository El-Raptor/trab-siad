# %%
####
## Celso Antonio Uliana Junior
## July 2 2020
####

import pandas as pd

#####
## Consuming and shaping the data to analysis
## Covid-19 numbers in Brazil by date
## Isolation percentage in Brazil by date
#####

data_raw_covid = pd.read_csv("C:/Users/PCDOMILHAO/Documents/GitHub/trab-siad/scripts/Jupyter-Notebook/dados/covidBrasil.csv", sep = ";", decimal = ",")
data_covid = data_raw_covid['Data'].values.copy()
data_covid = data_raw_covid.dropna().set_index("Data")

####
## Shaping a central pandas dataFrame for all our ML needs
####

data = data_covid

# %%
from sklearn.preprocessing import MinMaxScaler

####
## normalizing values for both covid and isolation percentage 
## between range [0,1] using sklearn MinMaxScaler
####

covid_norm = data_covid["Casos"].values.copy()
covid_norm.shape = (len(covid_norm), 1)

####
## Shaping the central dataFrame with normalized values
####
min_max_scaler = MinMaxScaler()

covid_norm = min_max_scaler.fit_transform(covid_norm)

data["CasosNormalizados"] = covid_norm
data.head(200)
# Out:
#          Casos  CasosNormalizados
# Data
# 26/2/20      1           0.000018
# 27/2/20      0           0.000000
# 28/2/20      0           0.000000
# 29/2/20      0           0.000000
# 1/3/20       1           0.000018
# ...        ...                ...
# 17/6/20  34918           0.637527
# 18/6/20  32188           0.587683
# 19/6/20  22765           0.415640
# 20/6/20  54771           1.000000
# 21/6/20  34666           0.632926
#
# [117 rows x 2 columns]

# %%
####
## Sliding window
## This example of sliding window looks at past data
####
df = pd.DataFrame()
window_size = 7
for i in range(0, window_size + 1):
    df['E{}'.format(i)] = data['CasosNormalizados'].shift(+i)
df = df.iloc[+window_size:]
print(df)
# Out:
#                E0        E1        E2        E3        E4        E5        E6  \
# Data
# 4/3/20   0.000000  0.000000  0.000000  0.000018  0.000000  0.000000  0.000000
# 5/3/20   0.000018  0.000000  0.000000  0.000000  0.000018  0.000000  0.000000
# 6/3/20   0.000091  0.000018  0.000000  0.000000  0.000000  0.000018  0.000000
# 7/3/20   0.000091  0.000091  0.000018  0.000000  0.000000  0.000000  0.000018
# 8/3/20   0.000000  0.000091  0.000091  0.000018  0.000000  0.000000  0.000000
# ...           ...       ...       ...       ...       ...       ...       ...
# 17/6/20  0.637527  0.376970  0.312392  0.396268  0.474375  0.555257  0.600920
# 18/6/20  0.587683  0.637527  0.376970  0.312392  0.396268  0.474375  0.555257
# 19/6/20  0.415640  0.587683  0.637527  0.376970  0.312392  0.396268  0.474375
# 20/6/20  1.000000  0.415640  0.587683  0.637527  0.376970  0.312392  0.396268
# 21/6/20  0.632926  1.000000  0.415640  0.587683  0.637527  0.376970  0.312392
#
#                E7
# Data
# 4/3/20   0.000018
# 5/3/20   0.000000
# 6/3/20   0.000000
# 7/3/20   0.000000
# 8/3/20   0.000018
# ...           ...
# 17/6/20  0.585912
# 18/6/20  0.600920
# 19/6/20  0.555257
# 20/6/20  0.474375
# 21/6/20  0.396268
#
# [110 rows x 8 columns]

# %%
####
## Manipulating the data to split into X(a window size of values)
## and target, or Y, the value X "produces"
####

arr = df.values

X = arr[:, 1:]
target = arr[:, 0]
#target = arr[:, -1]
#print(X)
#print(arr)
#print(target)

# %%
from sklearn import metrics
from sklearn.svm import SVR
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_predict

mlp = MLPRegressor(
    hidden_layer_sizes = (50,),  activation = 'relu', solver = 'adam', alpha = 0.001, batch_size = 'auto',
    learning_rate = 'constant', learning_rate_init = 0.01, power_t = 0.5, max_iter = 1000, shuffle = True,
    random_state = 9, tol = 0.0001, verbose = True, warm_start = False, momentum = 0.9, nesterovs_momentum = True,
    early_stopping = False, validation_fraction = 0.1, beta_1 = 0.9, beta_2 = 0.999, epsilon = 1e-08)
svr = SVR(kernel = 'linear', C = 0.25, epsilon = 0.01, verbose = True, max_iter = 1000)
lr = LinearRegression()

full_predict_lr = cross_val_predict(lr, X, target, cv = 10)
full_predict_mlp = cross_val_predict(mlp, X, target, cv = 10)
full_predict_svr = cross_val_predict(svr, X, target, cv = 10)
# Out:
# Iteration 1, loss = 0.02299486
# Iteration 2, loss = 0.01485870
# Iteration 3, loss = 0.00990159
# Iteration 4, loss = 0.00529995
# Iteration 5, loss = 0.00342768
# Iteration 6, loss = 0.00449443
# Iteration 7, loss = 0.00573461
# Iteration 8, loss = 0.00603868
# Iteration 9, loss = 0.00625136
# Iteration 10, loss = 0.00637758
# Iteration 11, loss = 0.00588828
# Iteration 12, loss = 0.00486324
# Iteration 13, loss = 0.00387186
# Iteration 14, loss = 0.00333691
# Iteration 15, loss = 0.00321202
# Iteration 16, loss = 0.00319692
# Iteration 17, loss = 0.00319216
# Iteration 18, loss = 0.00329905
# Iteration 19, loss = 0.00354189
# Iteration 20, loss = 0.00376468
# Iteration 21, loss = 0.00379597
# Iteration 22, loss = 0.00363827
# Iteration 23, loss = 0.00343096
# Iteration 24, loss = 0.00326434
# Iteration 25, loss = 0.00311680
# Iteration 26, loss = 0.00294412
# Iteration 27, loss = 0.00277921
# Iteration 28, loss = 0.00270788
# Iteration 29, loss = 0.00274182
# Iteration 30, loss = 0.00281365
# Iteration 31, loss = 0.00285573
# Iteration 32, loss = 0.00286412
# Iteration 33, loss = 0.00286824
# Iteration 34, loss = 0.00286497
# Iteration 35, loss = 0.00282222
# Iteration 36, loss = 0.00273695
# Iteration 37, loss = 0.00265174
# Iteration 38, loss = 0.00260274
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.02304768
# Iteration 2, loss = 0.01491437
# Iteration 3, loss = 0.00991631
# Iteration 4, loss = 0.00530096
# Iteration 5, loss = 0.00342795
# Iteration 6, loss = 0.00449535
# Iteration 7, loss = 0.00574093
# Iteration 8, loss = 0.00605389
# Iteration 9, loss = 0.00626989
# Iteration 10, loss = 0.00639087
# Iteration 11, loss = 0.00589394
# Iteration 12, loss = 0.00486498
# Iteration 13, loss = 0.00387141
# Iteration 14, loss = 0.00333452
# Iteration 15, loss = 0.00321008
# Iteration 16, loss = 0.00319617
# Iteration 17, loss = 0.00319372
# Iteration 18, loss = 0.00330253
# Iteration 19, loss = 0.00354589
# Iteration 20, loss = 0.00376841
# Iteration 21, loss = 0.00379899
# Iteration 22, loss = 0.00364045
# Iteration 23, loss = 0.00343210
# Iteration 24, loss = 0.00326434
# Iteration 25, loss = 0.00311574
# Iteration 26, loss = 0.00294312
# Iteration 27, loss = 0.00277905
# Iteration 28, loss = 0.00270816
# Iteration 29, loss = 0.00274273
# Iteration 30, loss = 0.00281472
# Iteration 31, loss = 0.00285708
# Iteration 32, loss = 0.00286538
# Iteration 33, loss = 0.00286913
# Iteration 34, loss = 0.00286549
# Iteration 35, loss = 0.00282247
# Iteration 36, loss = 0.00273699
# Iteration 37, loss = 0.00265367
# Iteration 38, loss = 0.00260304
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.02318354
# Iteration 2, loss = 0.01503557
# Iteration 3, loss = 0.00992826
# Iteration 4, loss = 0.00528665
# Iteration 5, loss = 0.00342245
# Iteration 6, loss = 0.00450432
# Iteration 7, loss = 0.00577706
# Iteration 8, loss = 0.00612126
# Iteration 9, loss = 0.00633890
# Iteration 10, loss = 0.00643493
# Iteration 11, loss = 0.00590795
# Iteration 12, loss = 0.00486286
# Iteration 13, loss = 0.00386199
# Iteration 14, loss = 0.00331719
# Iteration 15, loss = 0.00319344
# Iteration 16, loss = 0.00318726
# Iteration 17, loss = 0.00319652
# Iteration 18, loss = 0.00331744
# Iteration 19, loss = 0.00356763
# Iteration 20, loss = 0.00378970
# Iteration 21, loss = 0.00381569
# Iteration 22, loss = 0.00365059
# Iteration 23, loss = 0.00343456
# Iteration 24, loss = 0.00326003
# Iteration 25, loss = 0.00310827
# Iteration 26, loss = 0.00293631
# Iteration 27, loss = 0.00277506
# Iteration 28, loss = 0.00270809
# Iteration 29, loss = 0.00274660
# Iteration 30, loss = 0.00282224
# Iteration 31, loss = 0.00286645
# Iteration 32, loss = 0.00287404
# Iteration 33, loss = 0.00287463
# Iteration 34, loss = 0.00286720
# Iteration 35, loss = 0.00282147
# Iteration 36, loss = 0.00273421
# Iteration 37, loss = 0.00264931
# Iteration 38, loss = 0.00259863
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.02337101
# Iteration 2, loss = 0.01515637
# Iteration 3, loss = 0.00989193
# Iteration 4, loss = 0.00523695
# Iteration 5, loss = 0.00340300
# Iteration 6, loss = 0.00452618
# Iteration 7, loss = 0.00586682
# Iteration 8, loss = 0.00625787
# Iteration 9, loss = 0.00644557
# Iteration 10, loss = 0.00648829
# Iteration 11, loss = 0.00593421
# Iteration 12, loss = 0.00486719
# Iteration 13, loss = 0.00385134
# Iteration 14, loss = 0.00329021
# Iteration 15, loss = 0.00315834
# Iteration 16, loss = 0.00318201
# Iteration 17, loss = 0.00322248
# Iteration 18, loss = 0.00334511
# Iteration 19, loss = 0.00358303
# Iteration 20, loss = 0.00380027
# Iteration 21, loss = 0.00383615
# Iteration 22, loss = 0.00367354
# Iteration 23, loss = 0.00343840
# Iteration 24, loss = 0.00324206
# Iteration 25, loss = 0.00308511
# Iteration 26, loss = 0.00292396
# Iteration 27, loss = 0.00277161
# Iteration 28, loss = 0.00269827
# Iteration 29, loss = 0.00273454
# Iteration 30, loss = 0.00282208
# Iteration 31, loss = 0.00288044
# Iteration 32, loss = 0.00288894
# Iteration 33, loss = 0.00287947
# Iteration 34, loss = 0.00286307
# Iteration 35, loss = 0.00281656
# Iteration 36, loss = 0.00273048
# Iteration 37, loss = 0.00263903
# Iteration 38, loss = 0.00258328
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.02369666
# Iteration 2, loss = 0.01544102
# Iteration 3, loss = 0.00986606
# Iteration 4, loss = 0.00516111
# Iteration 5, loss = 0.00338407
# Iteration 6, loss = 0.00456173
# Iteration 7, loss = 0.00596223
# Iteration 8, loss = 0.00640921
# Iteration 9, loss = 0.00657785
# Iteration 10, loss = 0.00654054
# Iteration 11, loss = 0.00592564
# Iteration 12, loss = 0.00484078
# Iteration 13, loss = 0.00381037
# Iteration 14, loss = 0.00324000
# Iteration 15, loss = 0.00312007
# Iteration 16, loss = 0.00318610
# Iteration 17, loss = 0.00327851
# Iteration 18, loss = 0.00341482
# Iteration 19, loss = 0.00363265
# Iteration 20, loss = 0.00383563
# Iteration 21, loss = 0.00387288
# Iteration 22, loss = 0.00370904
# Iteration 23, loss = 0.00345202
# Iteration 24, loss = 0.00322172
# Iteration 25, loss = 0.00305427
# Iteration 26, loss = 0.00291348
# Iteration 27, loss = 0.00278479
# Iteration 28, loss = 0.00271262
# Iteration 29, loss = 0.00273777
# Iteration 30, loss = 0.00282818
# Iteration 31, loss = 0.00290471
# Iteration 32, loss = 0.00291968
# Iteration 33, loss = 0.00289288
# Iteration 34, loss = 0.00285732
# Iteration 35, loss = 0.00280883
# Iteration 36, loss = 0.00273200
# Iteration 37, loss = 0.00264238
# Iteration 38, loss = 0.00257968
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.02427960
# Iteration 2, loss = 0.01486507
# Iteration 3, loss = 0.00892014
# Iteration 4, loss = 0.00462252
# Iteration 5, loss = 0.00338099
# Iteration 6, loss = 0.00488243
# Iteration 7, loss = 0.00637725
# Iteration 8, loss = 0.00682279
# Iteration 9, loss = 0.00679273
# Iteration 10, loss = 0.00639249
# Iteration 11, loss = 0.00549735
# Iteration 12, loss = 0.00435683
# Iteration 13, loss = 0.00344903
# Iteration 14, loss = 0.00306570
# Iteration 15, loss = 0.00310591
# Iteration 16, loss = 0.00329553
# Iteration 17, loss = 0.00348549
# Iteration 18, loss = 0.00368229
# Iteration 19, loss = 0.00387424
# Iteration 20, loss = 0.00395695
# Iteration 21, loss = 0.00384057
# Iteration 22, loss = 0.00356701
# Iteration 23, loss = 0.00326789
# Iteration 24, loss = 0.00303888
# Iteration 25, loss = 0.00288564
# Iteration 26, loss = 0.00278866
# Iteration 27, loss = 0.00274480
# Iteration 28, loss = 0.00277818
# Iteration 29, loss = 0.00287299
# Iteration 30, loss = 0.00296035
# Iteration 31, loss = 0.00298235
# Iteration 32, loss = 0.00294078
# Iteration 33, loss = 0.00287167
# Iteration 34, loss = 0.00279468
# Iteration 35, loss = 0.00271118
# Iteration 36, loss = 0.00262497
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.02427275
# Iteration 2, loss = 0.01531519
# Iteration 3, loss = 0.00853314
# Iteration 4, loss = 0.00419382
# Iteration 5, loss = 0.00341187
# Iteration 6, loss = 0.00515959
# Iteration 7, loss = 0.00662803
# Iteration 8, loss = 0.00708675
# Iteration 9, loss = 0.00695023
# Iteration 10, loss = 0.00629516
# Iteration 11, loss = 0.00518514
# Iteration 12, loss = 0.00399934
# Iteration 13, loss = 0.00318533
# Iteration 14, loss = 0.00294179
# Iteration 15, loss = 0.00308998
# Iteration 16, loss = 0.00335298
# Iteration 17, loss = 0.00359396
# Iteration 18, loss = 0.00380657
# Iteration 19, loss = 0.00395576
# Iteration 20, loss = 0.00394558
# Iteration 21, loss = 0.00373962
# Iteration 22, loss = 0.00341775
# Iteration 23, loss = 0.00311360
# Iteration 24, loss = 0.00290479
# Iteration 25, loss = 0.00278379
# Iteration 26, loss = 0.00272274
# Iteration 27, loss = 0.00272267
# Iteration 28, loss = 0.00279191
# Iteration 29, loss = 0.00289357
# Iteration 30, loss = 0.00295503
# Iteration 31, loss = 0.00294240
# Iteration 32, loss = 0.00287705
# Iteration 33, loss = 0.00279306
# Iteration 34, loss = 0.00270584
# Iteration 35, loss = 0.00261844
# Iteration 36, loss = 0.00254778
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.02246374
# Iteration 2, loss = 0.01052430
# Iteration 3, loss = 0.00462768
# Iteration 4, loss = 0.00326934
# Iteration 5, loss = 0.00489517
# Iteration 6, loss = 0.00670255
# Iteration 7, loss = 0.00713253
# Iteration 8, loss = 0.00631864
# Iteration 9, loss = 0.00494117
# Iteration 10, loss = 0.00370133
# Iteration 11, loss = 0.00297513
# Iteration 12, loss = 0.00281423
# Iteration 13, loss = 0.00305463
# Iteration 14, loss = 0.00347196
# Iteration 15, loss = 0.00382876
# Iteration 16, loss = 0.00397799
# Iteration 17, loss = 0.00390278
# Iteration 18, loss = 0.00365607
# Iteration 19, loss = 0.00332288
# Iteration 20, loss = 0.00300248
# Iteration 21, loss = 0.00276864
# Iteration 22, loss = 0.00265826
# Iteration 23, loss = 0.00266212
# Iteration 24, loss = 0.00274662
# Iteration 25, loss = 0.00285780
# Iteration 26, loss = 0.00293659
# Iteration 27, loss = 0.00294763
# Iteration 28, loss = 0.00288910
# Iteration 29, loss = 0.00278006
# Iteration 30, loss = 0.00265762
# Iteration 31, loss = 0.00255880
# Iteration 32, loss = 0.00249880
# Iteration 33, loss = 0.00248068
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.01862870
# Iteration 2, loss = 0.00876705
# Iteration 3, loss = 0.00360674
# Iteration 4, loss = 0.00245504
# Iteration 5, loss = 0.00391205
# Iteration 6, loss = 0.00552043
# Iteration 7, loss = 0.00586250
# Iteration 8, loss = 0.00510268
# Iteration 9, loss = 0.00391584
# Iteration 10, loss = 0.00287789
# Iteration 11, loss = 0.00228705
# Iteration 12, loss = 0.00218342
# Iteration 13, loss = 0.00240859
# Iteration 14, loss = 0.00275414
# Iteration 15, loss = 0.00304206
# Iteration 16, loss = 0.00317727
# Iteration 17, loss = 0.00312945
# Iteration 18, loss = 0.00294110
# Iteration 19, loss = 0.00268595
# Iteration 20, loss = 0.00242207
# Iteration 21, loss = 0.00220857
# Iteration 22, loss = 0.00208731
# Iteration 23, loss = 0.00206151
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Iteration 1, loss = 0.01457441
# Iteration 2, loss = 0.00652509
# Iteration 3, loss = 0.00233530
# Iteration 4, loss = 0.00154142
# Iteration 5, loss = 0.00276267
# Iteration 6, loss = 0.00399705
# Iteration 7, loss = 0.00414366
# Iteration 8, loss = 0.00340950
# Iteration 9, loss = 0.00238651
# Iteration 10, loss = 0.00157086
# Iteration 11, loss = 0.00118697
# Iteration 12, loss = 0.00122189
# Iteration 13, loss = 0.00151135
# Iteration 14, loss = 0.00183505
# Iteration 15, loss = 0.00202347
# Iteration 16, loss = 0.00202729
# Iteration 17, loss = 0.00187084
# Iteration 18, loss = 0.00162653
# Iteration 19, loss = 0.00137400
# Iteration 20, loss = 0.00117667
# Iteration 21, loss = 0.00107600
# Iteration 22, loss = 0.00107865
# Iteration 23, loss = 0.00115411
# Iteration 24, loss = 0.00125259
# Iteration 25, loss = 0.00132440
# Iteration 26, loss = 0.00133569
# Iteration 27, loss = 0.00128574
# Iteration 28, loss = 0.00119789
# Iteration 29, loss = 0.00110399
# Iteration 30, loss = 0.00103350
# Iteration 31, loss = 0.00100091
# Iteration 32, loss = 0.00100459
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]

# %%
print('Mean Squared Error in MLP: %s' %(metrics.mean_squared_error(target, full_predict_mlp)))
print('Mean Squared Error in SVR: %s' %(metrics.mean_squared_error(target, full_predict_svr)))
print('Mean Squared Error in LR: %s' %(metrics.mean_squared_error(target, full_predict_lr)))

print(len(full_predict_mlp))
print(len(full_predict_svr))
print(len(full_predict_lr))

print(len(data['CasosNormalizados']))
# Out:
# Mean Squared Error in MLP: 0.005627282287031134
# Mean Squared Error in SVR: 0.005503692025207881
# Mean Squared Error in LR: 0.00599490799826504
# 110
# 110
# 110
# 117

# %%
import numpy as np

values_to_add = list()
for i in range(0, window_size):
    values_to_add.append(float('NaN'))
    
full_predict_svr = np.insert(full_predict_svr, 0, values_to_add)
full_predict_svr.shape = (len(full_predict_svr), 1)
    
full_predict_mlp = np.insert(full_predict_mlp, 0, values_to_add)
full_predict_mlp.shape = (len(full_predict_mlp), 1)

full_predict_lr = np.insert(full_predict_lr, 0, values_to_add)
full_predict_lr.shape = (len(full_predict_lr), 1)

print(full_predict_svr.shape)
print(full_predict_mlp.shape)
print(full_predict_lr.shape)
# Out:
# (117, 1)
# (117, 1)
# (117, 1)

# %%
data['Predict_lr'] = full_predict_lr
data['Predict_mlp'] = full_predict_mlp
data['Predict_svr'] = full_predict_svr
data
# Out:
#          Casos  CasosNormalizados  Predict_lr  Predict_mlp  Predict_svr
# Data
# 26/2/20      1           0.000018         NaN          NaN          NaN
# 27/2/20      0           0.000000         NaN          NaN          NaN
# 28/2/20      0           0.000000         NaN          NaN          NaN
# 29/2/20      0           0.000000         NaN          NaN          NaN
# 1/3/20       1           0.000018         NaN          NaN          NaN
# ...        ...                ...         ...          ...          ...
# 17/6/20  34918           0.637527    0.649064     0.571081     0.578973
# 18/6/20  32188           0.587683    0.721236     0.623626     0.630908
# 19/6/20  22765           0.415640    0.610291     0.575839     0.574648
# 20/6/20  54771           1.000000    0.497290     0.455153     0.470229
# 21/6/20  34666           0.632926    0.657183     0.532949     0.595835
#
# [117 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
data.plot(y=['CasosNormalizados', 'Predict_mlp', 'Predict_svr', 'Predict_lr'], style=['-s', '--o'])
plt.show()
